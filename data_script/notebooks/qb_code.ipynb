# %%
import sys
# !{sys.executable} -m pip install -r ../requirements.txt

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url = 'https://www.espn.com/nfl/weekly/leaders/_/week/1/type/passing'

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://www.espn.com/', # Good practice
}

# %%
res = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(res.text, "html.parser")

# %%
tables = soup.find_all('table')

# %%
len(tables)
# Out:
# 7

# %%
qb_table = tables[6]

# %%
rows = qb_table.find_all('tr')

# %%
rows[2:len(rows)]
# Out:
# [<tr align="right" class="oddrow player-28-3918298">
#  <td align="left">1</td><td align="left"><a href="https://www.espn.com/nfl/player/_/id/3918298/josh-allen">Josh Allen</a>, QB</td><td align="left">BUF</td><td align="left"><span class="greenfont">W</span> <a href="/nfl/boxscore?gameId=401772918">41-40</a>  vs. BAL</td><td>33</td><td>46</td><td class="sortcell">394</td><td>2</td><td>0</td><td>1</td><td>0</td><td>112.0</td></tr>,
#  <tr align="right" class="evenrow player-28-15864">
#  <td align="left">2</td><td align="left"><a href="https://www.espn.com/nfl/player/_/id/15864/geno-smith">Geno Smith</a>, QB</td><td align="left">LV</td><td align="left"><span class="greenfont">W</span> <a href="/nfl/boxscore?gameId=401772720">20-13</a>  at NE</td><td>24</td><td>34</td><td class="sortcell">362</td><td>1</td><td>1</td><td>4</td><td>0</td><td>102.8</td></tr>,
#  <tr align="right" class="oddrow player-28-4038941">
# ...

# %%
mod = soup.find('div', class_ ='mod-content')

# %%
anchors = mod.find_all('a')

# %%
anchors
# Out:
# [<a href="//www.espn.com/nfl/weekly/leaders/_/week/1">All</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/1/type/rushing">Rushing</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/1/type/receiving">Receiving</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/1/type/defensive">Defensive</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/2/type/passing">2</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/3/type/passing">3</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/4/type/passing">4</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/5/type/passing">5</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/6/type/passing">6</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/7/type/passing">7</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/8/type/passing">8</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/9/type/passing">9</a>,
# ...

# %%
 anchors_f = anchors[4:]

# %%
 anchors_f
# Out:
# [<a href="//www.espn.com/nfl/weekly/leaders/_/week/2/type/passing">2</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/3/type/passing">3</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/4/type/passing">4</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/5/type/passing">5</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/6/type/passing">6</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/7/type/passing">7</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/8/type/passing">8</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/9/type/passing">9</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/10/type/passing">10</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/11/type/passing">11</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/12/type/passing">12</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/13/type/passing">13</a>,
#  <a href="//www.espn.com/nfl/weekly/leaders/_/week/14/type/passing">14</a>,
# ...

# %%
a_list = []
for a in  anchors_f:
    a_list.append(a['href'][2:])

# %%
a_list
# Out:
# ['www.espn.com/nfl/weekly/leaders/_/week/2/type/passing',
#  'www.espn.com/nfl/weekly/leaders/_/week/3/type/passing',
#  'www.espn.com/nfl/weekly/leaders/_/week/4/type/passing',
#  'www.espn.com/nfl/weekly/leaders/_/week/5/type/passing',
#  'www.espn.com/nfl/weekly/leaders/_/week/6/type/passing',
#  'www.espn.com/nfl/weekly/leaders/_/week/7/type/passing',
#  'www.espn.com/nfl/weekly/leaders/_/week/8/type/passing',
#  'www.espn.com/nfl/weekly/leaders/_/week/9/type/passing',
#  'www.espn.com/nfl/weekly/leaders/_/week/10/type/passing',
#  'www.espn.com/nfl/weekly/leaders/_/week/11/type/passing',
#  'www.espn.com/nfl/weekly/leaders/_/week/12/type/passing',
#  'www.espn.com/nfl/weekly/leaders/_/week/13/type/passing',
#  'www.espn.com/nfl/weekly/leaders/_/week/14/type/passing',
#  'www.espn.com/nfl/weekly/leaders/_/type/passing']
